# %%
import os
from os import listdir
from os.path import join
import numpy as np
import glob
import nibabel as nib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATASET_ROOT = '/home/cszsolnai/datasets/MICCAI_BraTS_2018_Data_Training'
HGG = join(DATASET_ROOT, 'HGG')
LGG = join(DATASET_ROOT, 'LGG')

# Slice can be from 0 to 154
SLICE = 80

# %%
hgg_dirs = [e for e in glob.glob(HGG + '/*')]

# %%
hgg_day = [e for e in glob.glob(hgg_dirs[1] + '/*')]

# %%
img_t1ce = nib.load([e for e in hgg_day if 't1ce.nii' in e][0])
img_flair = nib.load([e for e in hgg_day if 'flair.nii' in e][0])
img_t1 = nib.load([e for e in hgg_day if 't1.nii' in e][0])
img_t2 = nib.load([e for e in hgg_day if 't2.nii' in e][0])
seg = nib.load([e for e in hgg_day if 'seg.nii' in e][0])

# %%
img_t1ce_data = img_t1ce.get_data()
img_flair_data = img_flair.get_data()
img_t1_data = img_t1.get_data()
img_t2_data = img_t2.get_data()
seg_data = seg.get_data()

# %%
# Plot whole brain image
plt.imshow(seg_data[:, :, SLICE])

# %%
set(list(seg_data[:, :, SLICE].flatten()))
# Out:
# {0, 1, 2, 4}

# %%
plt.imshow(img_t1ce_data[:, :, SLICE])

# %%
plt.imshow(img_flair_data[:, :, SLICE])

# %%
plt.imshow(img_t1_data[:, :, SLICE])

# %%
plt.imshow(img_t2_data[:, :, SLICE])
